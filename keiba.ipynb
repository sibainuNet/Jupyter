# %%
import pandas as pd 
url = 'https://db.netkeiba.com/race/201902010101'
pd.read_html(url)
# Out:
# [    着順  枠番  馬番         馬名  性齢  斤量    騎手     タイム     着差     単勝    人気       馬体重  \
#  0    1   6  12   アドマイヤデルタ  牡3  56  吉田隼人  1:08.9    NaN    4.0   3.0  490(+32)
#  1    2   3   5      ティレニア  牝3  54  藤岡佑介  1:09.1  1.1/2    3.7   2.0   442(+4)
#  2    3   4   7  ドゥシャンパーニュ  牝3  54  北村友一  1:09.3      1    2.9   1.0   428(-4)
#  3    4   5  10  シャイニーブランコ  牡3  56  岩田康誠  1:09.5  1.1/2   10.3   5.0   442(+2)
#  4    5   4   8    シュンカジョウ  牝3  54  松岡正海  1:09.6     クビ   57.5   8.0  438(+14)
#  5    6   1   2        ビッケ  牡3  56  柴山雄一  1:09.6    アタマ    5.9   4.0   442(-8)
#  6    7   5   9   ジャスパーマリン  牝3  54  勝浦正樹  1:09.7    1/2   94.7   9.0    456(0)
#  7    8   2   4     ブランダード  牝3  51  団野大成  1:10.1  2.1/2  187.2  12.0  368(-10)
#  8    9   1   1  スプリングハズカム  牝3  54  菱田裕二  1:10.6      3  104.7  10.0  516(+22)
#  9   10   8  15  チェインドレディー  牝3  54  丹内祐次  1:11.0  2.1/2   14.7   6.0   404(-4)
#  10  11   2   3  キョウエイシンシア  牝3  54   荻野極  1:11.1    1/2   48.4   7.0   422(-6)
# ...
